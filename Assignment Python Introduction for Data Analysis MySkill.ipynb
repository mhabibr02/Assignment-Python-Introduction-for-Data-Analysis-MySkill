# %% [markdown]
# # IMPORT DATASET

# %%
# import dataset use library pandas

import pandas as pd

df = pd.read_csv('Dataset Excel - Python Introduction for Data Analysis.csv')

# %% [markdown]
# # LOAD DATASET

# %%
# display dataset 5 row first

df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3       33311   South  FUR-TA-10000577        Furniture       Tables
# 4       33311   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]
# Warning: Total number of columns (21) exceeds max_columns (20) limiting to first (20) columns.

# %% [markdown]
# # TAIL DATASET

# %%
# display dataset 5 row last

df.tail()
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9989    9990  CA-2014-110422  1/21/2014  1/23/2014    Second Class
# 9990    9991  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9991    9992  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9992    9993  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9993    9994  CA-2017-119914   5/4/2017   5/9/2017    Second Class
#
#      Customer ID     Customer Name   Segment        Country         City  ...  \
# 9989    TB-21400  Tom Boeckenhauer  Consumer  United States        Miami  ...
# 9990    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9991    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9992    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220      Chris Cortes  Consumer  United States  Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# 9989       33180   South  FUR-FU-10001889        Furniture  Furnishings
# 9990       92627    West  FUR-FU-10000747        Furniture  Furnishings
# 9991       92627    West  TEC-PH-10003645       Technology       Phones
# 9992       92627    West  OFF-PA-10004041  Office Supplies        Paper
# 9993       92683    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name    Sales  Quantity  \
# 9989                             Ultra Door Pull Handle   25.248         3
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.960         2
# 9991                              Aastra 57i VoIP phone  258.576         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.600         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# 9991       0.2  19.3932
# 9992       0.0  13.3200
# 9993       0.0  72.9480
#
# [5 rows x 21 columns]

# %% [markdown]
# # SAMPLE DATASET

# %%
# display dataset 5 row random

df.sample(5)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 4168    4169  CA-2014-157924  10/11/2014  10/13/2014     First Class
# 5334    5335  CA-2014-103331   8/26/2014    9/1/2014  Standard Class
# 2199    2200  CA-2015-135363   3/28/2015    4/2/2015  Standard Class
# 9935    9936  CA-2016-114405    4/7/2016   4/12/2016  Standard Class
# 7437    7438  CA-2014-165568   2/15/2014   2/19/2014  Standard Class
#
#      Customer ID        Customer Name    Segment        Country          City  \
# 4168    HA-14920       Helen Andreada   Consumer  United States      Pasadena
# 5334    KB-16315           Karl Braun   Consumer  United States        Newark
# 2199    CK-12205  Chloris Kastensmidt   Consumer  United States  Philadelphia
# 9935    AS-10240         Alan Shonely   Consumer  United States  Philadelphia
# 7437    BF-11020    Barry Französisch  Corporate  United States       Seattle
#
#       ... Postal Code  Region       Product ID         Category Sub-Category  \
# 4168  ...       91104    West  FUR-CH-10000229        Furniture       Chairs
# 5334  ...       19711    East  OFF-PA-10002160  Office Supplies        Paper
# 2199  ...       19120    East  OFF-PA-10000533  Office Supplies        Paper
# 9935  ...       19120    East  OFF-ST-10001627  Office Supplies      Storage
# 7437  ...       98105    West  OFF-BI-10001031  Office Supplies      Binders
#
#                                            Product Name    Sales  Quantity  \
# 4168  Global Enterprise Series Seating High-Back Swi...  433.568         2
# 5334                                         Xerox 1978   17.340         3
# 2199             Southworth Parchment Paper & Envelopes    5.232         1
# 9935  Eldon Jumbo ProFile Portable File Boxes Graphi...   36.744         3
# 7437            Pressboard Data Binders by Wilson Jones   21.360         5
#
#       Discount   Profit
# 4168       0.2 -65.0352
# 5334       0.0   8.4966
# 2199       0.2   1.7004
# 9935       0.2   3.6744
# 7437       0.2   7.2090
#
# [5 rows x 21 columns]

# %% [markdown]
# # CONVERT DATASET

# %%
# convert dataset to spreadsheet

from google.colab import sheets

sheet = sheets.InteractiveSheet(df=df)
# Out:
# https://docs.google.com/spreadsheets/d/1KItLF_yf_jXoVCyTchedy-vNn64BaEjlsi7JiKWWRgA#gid=0
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/1KItLF_yf_jXoVCyTchedy-vNn64BaEjlsi7JiKWWRgA#gid=0/edit?rm=embedded?usp=sharing?widget=true&amp;headers=false"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # INFO DATASET

# %%
# check info dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
#  19  Discount       9994 non-null   float64
#  20  Profit         9994 non-null   float64
# dtypes: float64(3), int64(3), object(15)
# memory usage: 1.6+ MB

# %% [markdown]
# # VISUALIZATION DATASET

# %%
# import chart use matplotlib

import matplotlib.pyplot as plt

# %%
# display chart from sales

df['Sales'].plot()
plt.title('Sales')
# Out:
# Text(0.5, 1.0, 'Sales')

# %%
# display chart from quantity

df['Quantity'].plot()
plt.title('Quantity')
# Out:
# Text(0.5, 1.0, 'Quantity')

# %%
# display chart from discount

df['Discount'].plot()
plt.title('Discount')
# Out:
# Text(0.5, 1.0, 'Discount')

# %%
# display chart from profit

df['Profit'].plot()
plt.title('Profit')
# Out:
# Text(0.5, 1.0, 'Profit')
